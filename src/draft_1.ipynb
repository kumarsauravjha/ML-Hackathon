# %%
import easyocr

# %%
# Create an OCR reader object
reader = easyocr.Reader(['en'])

# Read text from an image
result = reader.readtext('D:/STUDY/MS/Amazon ML Hackathon 2024/student_resource 3/images/41-NCxNuBxL.jpg')

# Print the extracted text
for detection in result:
    print(detection[1])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 2OCM
# 1SCM

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %%
text = pytesseract.image_to_string('D:/STUDY/MS/Amazon ML Hackathon 2024/student_resource 3/images/41nblnEkJ3L.jpg')
print(text)
# Out:
# sow=40W
# 470 Im

# %%
import cv2
import pytesseract

# Load the image
image_path = 'D:/STUDY/MS/Amazon ML Hackathon 2024/student_resource 3/images/41nblnEkJ3L.jpg'
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding
thresh = cv2.adaptiveThreshold(
    gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2
)

# Remove noise using median blurring
# blur = cv2.medianBlur(thresh, 3)

# Optionally, resize the image for better accuracy (if needed)
resize = cv2.resize(thresh, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)

# Apply Tesseract to the processed image
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'
text2 = pytesseract.image_to_string(resize)

print(text2)
# Out:
# — =40w
#
# Ge SAN | 470 im

# %%
text3 = pytesseract.image_to_string(resize)
print(text3)
# Out:
# dt dh =

# %%
#to plot the image
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.imshow(resize, cmap='gray')
plt.axis('off')
plt.show()
