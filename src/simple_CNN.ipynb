# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from PIL import Image
import os
import pandas as pd

# %%
sample_test=pd.read_excel('D:/STUDY/MS/Amazon ML Hackathon 2024/student_resource 3/dataset/new_sample_train.xls.xlsx')

# %%
# Step 1: Image Preprocessing
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize images to 128x128
    transforms.ToTensor(),          # Convert images to PyTorch tensors
    transforms.Normalize((0.5,), (0.5,))  # Normalize to range [-1, 1]
])

# Load images into PyTorch tensor format
def load_image(image_path):
    image = Image.open(image_path)  # Open the image
    image = transform(image)        # Apply the transformations
    return image

# Load the images (assuming you have the file paths and entity names)
image_paths = sample_test['image_link'].tolist()  # Ensure this contains the paths to your downloaded images
image_dir = 'D:/STUDY/MS/Amazon ML Hackathon 2024/student_resource 3/images2'

images = []
for img_url in image_paths:
    img_name = img_url.split('/')[-1]
    local_image_path = os.path.join(image_dir, img_name)
    if os.path.exists(local_image_path):
        images.append(load_image(local_image_path))  # Preprocess each image

# Stack images into a tensor
X = torch.stack(images)

y = torch.randint(0, 2, (len(images),))  # Random binary labels for text region presence/absence

# %%
# Step 2: CNN Model for Text Region Detection
class SimpleTextRegionCNN(nn.Module):
    def __init__(self):
        super(SimpleTextRegionCNN, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)  # 3 input channels (RGB), 16 output channels
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(32 * 32 * 32, 128)  # Fully connected layer
        self.fc2 = nn.Linear(128, 2)  # Output layer (2 classes: text-heavy region vs. non-text-heavy region)
    
    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 32 * 32 * 32)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Step 3: Initialize the Model, Loss Function, and Optimizer
model = SimpleTextRegionCNN()
criterion = nn.CrossEntropyLoss()  # Use cross-entropy loss for classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer

# %%
# Step 4: Training the CNN
num_epochs = 5  # Keep it small for testing
batch_size = 8

# Training loop
for epoch in range(num_epochs):
    running_loss = 0.0
    for i in range(0, len(X), batch_size):
        inputs = X[i:i+batch_size]
        labels = y[i:i+batch_size]
        
        optimizer.zero_grad()  # Zero the parameter gradients

        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Calculate loss

        loss.backward()  # Backpropagate
        optimizer.step()  # Optimize

        running_loss += loss.item()
        if i % (batch_size * 2) == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / (i+1):.4f}")

print('Finished Training')
# Out:
# Epoch [1/5], Loss: 0.7044
# Epoch [1/5], Loss: 0.1461
# Epoch [1/5], Loss: 0.1195
# Epoch [1/5], Loss: 0.1097
# Epoch [1/5], Loss: 0.1165
# Epoch [1/5], Loss: 0.1093
# Epoch [1/5], Loss: 0.1095
# Epoch [1/5], Loss: 0.1106
# Epoch [1/5], Loss: 0.1076
# Epoch [1/5], Loss: 0.1054
# Epoch [1/5], Loss: 0.1041
# Epoch [1/5], Loss: 0.1025
# Epoch [1/5], Loss: 0.1012
# Epoch [2/5], Loss: 0.6459
# Epoch [2/5], Loss: 0.1156
# Epoch [2/5], Loss: 0.0969
# Epoch [2/5], Loss: 0.0917
# Epoch [2/5], Loss: 0.0898
# Epoch [2/5], Loss: 0.0870
# Epoch [2/5], Loss: 0.0851
# Epoch [2/5], Loss: 0.0831
# Epoch [2/5], Loss: 0.0829
# Epoch [2/5], Loss: 0.0816
# Epoch [2/5], Loss: 0.0816
# Epoch [2/5], Loss: 0.0810
# Epoch [2/5], Loss: 0.0806
# Epoch [3/5], Loss: 0.5384
# Epoch [3/5], Loss: 0.0899
# Epoch [3/5], Loss: 0.0683
# Epoch [3/5], Loss: 0.0687
# Epoch [3/5], Loss: 0.0690
# Epoch [3/5], Loss: 0.0671
# Epoch [3/5], Loss: 0.0747
# Epoch [3/5], Loss: 0.0762
# Epoch [3/5], Loss: 0.0741
# Epoch [3/5], Loss: 0.0718
# Epoch [3/5], Loss: 0.0720
# Epoch [3/5], Loss: 0.0697
# Epoch [3/5], Loss: 0.0678
# Epoch [4/5], Loss: 0.5071
# Epoch [4/5], Loss: 0.0988
# Epoch [4/5], Loss: 0.0726
# Epoch [4/5], Loss: 0.0684
# Epoch [4/5], Loss: 0.0658
# Epoch [4/5], Loss: 0.0701
# Epoch [4/5], Loss: 0.0719
# Epoch [4/5], Loss: 0.0685
# Epoch [4/5], Loss: 0.0665
# Epoch [4/5], Loss: 0.0638
# Epoch [4/5], Loss: 0.0620
# Epoch [4/5], Loss: 0.0596
# Epoch [4/5], Loss: 0.0577
# Epoch [5/5], Loss: 0.2436
# Epoch [5/5], Loss: 0.0519
# Epoch [5/5], Loss: 0.0412
# Epoch [5/5], Loss: 0.0393
# Epoch [5/5], Loss: 0.0392
# Epoch [5/5], Loss: 0.0363
# Epoch [5/5], Loss: 0.0355
# Epoch [5/5], Loss: 0.0345
# Epoch [5/5], Loss: 0.0347
# Epoch [5/5], Loss: 0.0346
# Epoch [5/5], Loss: 0.0339
# Epoch [5/5], Loss: 0.0326
# Epoch [5/5], Loss: 0.0314
# Finished Training

# %%
import cv2
import numpy as np
from PIL import Image
import pytesseract

# Function to preprocess the image for OCR
def preprocess_image_for_ocr(image):
    # Convert the image to grayscale
    gray_image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2GRAY)
    
    # Apply binary thresholding (convert image to black and white)
    _, thresholded_image = cv2.threshold(gray_image, 150, 255, cv2.THRESH_BINARY)
    
    # Optional: Apply Gaussian blur to reduce noise
    denoised_image = cv2.GaussianBlur(thresholded_image, (5, 5), 0)
    
    return denoised_image

# Dictionary to store the results {image_link: extracted_text}
results = {}

# Use the CNN to get predictions for text-heavy regions
model.eval()  # Set the model to evaluation mode

# Loop over all images in X and apply preprocessing + OCR to detected text regions
for i in range(len(X)):
    input_image = X[i].unsqueeze(0)  # Add a batch dimension
    output = model(input_image)  # Get the CNN output
    _, predicted = torch.max(output, 1)  # Predicted label (1: text-heavy, 0: no text)
    
    img_path = image_paths[i]  # Get the image link corresponding to the current image
    img_name = img_path.split('/')[-1]
    local_image_path = os.path.join(image_dir, img_name)

    if predicted.item() == 1:  # If text-heavy region detected
        print(f"Text region detected in image {i}.")
        
        # Open the image using PIL
        image = Image.open(local_image_path)
        
        # Preprocess the image for OCR
        preprocessed_image = preprocess_image_for_ocr(image)
        
        # Use Tesseract to extract text from the preprocessed image
        extracted_text = pytesseract.image_to_string(preprocessed_image)
        print(f"Extracted Text from Image {i}: {extracted_text}")
        
        # Store the result in the dictionary, associating the image link with the extracted text
        results[img_path] = extracted_text
    else:
        print(f"No text detected in image {i}.")
        results[img_path] = "No text detected."

# At the end, `results` will contain each `image_link` as the key and the `extracted_text` as the value
# Out:
# Text region detected in image 0.
# Extracted Text from Image 0: PROPSS
#
# NATURE
#
# Acie 100% pure et naturelle, la tere de
# Soameiéres px tsente des propwidnes abs “s
#
#
# No text detected in image 1.
# No text detected in image 2.
# Text region detected in image 3.
# Extracted Text from Image 3:
# Text region detected in image 4.
# Extracted Text from Image 4: PSYLLIUM
#
# HUSK
#
# FRE
#
#
# Text region detected in image 5.
# Extracted Text from Image 5: * Naturally-Sourced Psyllium
#
#  ———,,
#
# * High strength 1400mg
# per serving
# NS
#
# LANTAGO
# Plant SEEDS
#
# * Suitable for Vegans & Vegetarians
#
# ,
#
# Horbaach
#
# Text region detected in image 6.
# Extracted Text from Image 6: Directions: For adults, take two (2) vegan capsules
# daily, preferably with a meal. Do not exceed stated dose.
#
# Nutrition Information
#
# HIGH ST “Typleally Per Daily Dose
# Psyllium Husk Powder 1400mg
#
# Ingredients: Psyllium Husk Powder, Capsule Shell (Hy-
# droxypropylmethylcellulose), Anti-Caking Agents (Mag-
#
# nesium Salts of Fatty Acids, Silicon Dioxide).
# May contain Sesame Seeds & Mustard. For allergens,
# see the ingredients in bold.
#
# Notice: Take this product with 220ml of fluids. Taking
# this product without adequate fluid may cause the pos-
#
# sibility of choking. Do not use this product if you have
# 1 4 @) @) MG PLANTAGO OVATA difficulty swallowing. If you experience chest pain, vom-
# PLANT SEEDS iting or difficulty in swallowing or breathing after taking
#
# this product, seek immediate medical attention. Do not
# take before sleeping. Fibre products can affect the ab-
# sorption of many medications. Do not take this product
# within 1.5 hours of taking medication.
#
# Free From: Artificial Colour, Artificial Flavour, Artificial
# Sweetener, Preservatives.
#
# Rr
#
# x re} 6 : SUITABLE FOR VEGETARIANS & VEGANS
#
# HU16790 C
#
# Horbaach
#
# No text detected in image 7.
# Text region detected in image 8.
# Extracted Text from Image 8: Horbaach
#
# 100%
#
# HIGHEST
# QUALITY
#
# PSYLLIUM
# HUSK
#
# _ PLANTAGO OVATA
#
# PLANT SEEDS
# 3652
# : CAPSULES:
#
# Horbaach
#
# Text region detected in image 9.
# Extracted Text from Image 9: NEW LOOK.
# SAME TRUSTED QUALITY.
#
# HIGH STRENGTH
#
# PSYLLIUM Wiow $1
# HUSK PSYLLIUM
# HUSK
#
# ys Eee
#
# FOOD
# SUPPLEMENT oP QD) ad CAPSULES
#
# ~ Horbadach’
#
# No text detected in image 10.
# No text detected in image 11.
# Text region detected in image 12.
# Extracted Text from Image 12: fi Helps in ,
# osteoarthritis Helps In
# MM digestion
#
# ~Reduces
# inflammation
# 7
#
# t
#
# ost
#
# Anti-bacterial’
# properties ,
#
# Helps in
#
# Text region detected in image 13.
# Extracted Text from Image 13: Pais A PROMOTES
#
# iM ODIGESTIVE HEALTH
# IGH IN ANTIOXIDANTS
# + COMBATS DISEASES
#
#
# Text region detected in image 14.
# Extracted Text from Image 14: PACKAGING CHANGED
#
# wi,
#
# USDA
#
# is
# ~
# ~
# >
#
# AIC
#
# GANICS
#
# Ow body is © temple ond p
# natural foods Is the hey to make it run
#
# «h<
#
# Vr ia Vo Vo Vr
#
# q<
# AAR
# a oe
#
# WWW. SORICHORGANICS.COM
#
# & ®& > Comey of Crgh : cde
#
# Nutritional Facts ~
# {Nutritional Fac a a
# Colories 80keo! =
#
# MaNuracTURED an AND MARKETED BY: —
# Serich Organics Pe Ud. —
#
# No-63, Hock 6, Secor-63, Goren ;
# teddha Nogor, Une redo oo Consume withia 2 months cher opening the packet.
# For customer feedbock : NET WEIGHT : 100 g (3-53 oz} oe
# — #91-73903330675 at .
# cr P rahvarsesiyes reneeah Ree MRP Rs. : ©
#
# cor/ won
#
# begrencom/sach argon! BATCH NO, :
# ‘ond ge :
# Seis PRD. '
# SRS Use BY: Z
#
# Note: Packaging may vary for a brief period of time.
#
# No text detected in image 15.
# No text detected in image 16.
# No text detected in image 17.
# No text detected in image 18.
# Text region detected in image 19.
# Extracted Text from Image 19: _ ee ~~;
#
# vvvy
# WV VV Vy ye
#
# F Glucon-D
#
# Regular 20
#
# yVVVVVVWVWY
#
# VvVV vy wey VVVVV WV VY.
#
# GI
#
# pack
#
# xAN
#
# ENERGY
#
# 4
#
# 0 \
# 4)
# 4% N
#
#
# No text detected in image 20.
# Text region detected in image 21.
# Extracted Text from Image 21: ONE SIZE FITS ALL
#
# BLACK FABRIC BLOCKS
#
# STRETCHABLE AND
# THE LIGHT
#
# FORM FITTING
#
# EXPERT-GRADE GEL
# NON-TOXIC NO SMELL
#
# FLEXIBLE COMFORTABLE FOR
# COLD OR HOT THERAPY .
# 3.11n
#
# '
#
# ul €°G
#
# : 22.2 in
#
# Text region detected in image 22.
# Extracted Text from Image 22: 925 Sterling Silver
# 18K Gold Plated
#
# High Polish
# oe
# 0.07 INcH
# (1.8 MM) t ,
# \ /
# 16+2 INCH Extend Chain
# Net Weight: 2.7G (405MM+S0MM)
#
# Manual measurement, the size may be slightly different from the physical.
#
# No text detected in image 23.
# No text detected in image 24.
# No text detected in image 25.
# Text region detected in image 26.
# Extracted Text from Image 26: Product Name Harvest Festival Doll
#
# 15x9x26CM
# 52x42x40CM
# [ Material = Polyester material
#
# Craftsmanship Manual
#
# Grey . Orange
#
#
# No text detected in image 27.
# Text region detected in image 28.
# Extracted Text from Image 28: oe SD.
# NUVIDA “4b*
#
# NATURAL HEALTH
#
# Fe
#
# CRANBERRY EXTRACT
# High Strength Extract for
#
# Urinary Tract and Bladder Support
#
# SUITABLE FOR VEGETARIANS AND VEGANS
#
# 5000mg 90 Tablets
# Food Supplement
#
# Text region detected in image 29.
# Extracted Text from Image 29: SI FAP U@MIEARS HEAD
# BALA OIIS BUNS PrsSpnr
#
# UM oONAeSyD
# 1544 OS
#
# 50 ml
#
# Carvomin
#
# Verdauungstropfen
#
# 18,55 g/20 ml
# Flussigkeit zum Einnehmen
#
# Cy
#
# Wirkstoff:
#
# Auszug aus einer Mischung
# von Angelikawurzeln,
# Benediktenkraut und
#
# Pfefferminzblattern
#
# KL3NGE
#
# PHARMA
#
#
# Text region detected in image 30.
# Extracted Text from Image 30: MYR Cer ern ey ep
#
# > gn
# ,
# eer erenrs wer oo ene ce
# ot EES
# yer ow
#
# 50 ml
#
# Carvomin &
#
# f
# Verdauungstropfen ait gt
#
# 18,55 8/20 ml
# Flussigkeit zum Einnehmen
#
# ey
# Wg
# 1 gl
# é io
# i " 50 ml wirkstoff: *-
# f » Benediktent:.
# Carvomin pies:
# ) " Verdauungstropfen joi ;
#
# Mischurg s *
# 18,55 g/20 ml ferminzblat”
# nfl A Fllssigkeit zum Enthalt S8 «°°
# Wirkstoff: Yet Einnehmen
# Auszug aus einer Mischung 1
# von Angelikawurzetn,
#
# Benediktenkraut und ey in ae
# Pfefferminzblattern 6 nei
#
# K Lon G E Zur Anwendung
#
# bei Erwachsenen
# PHARMA
#
# Text region detected in image 31.
# Extracted Text from Image 31: Nek Be SE SSS
#
# Wee ASS SSE IEE SE EE
# SASS EES
#
# A OS
#
# a i 50 mi
# mall _
# , Carvomin
# ty, Verdauungstropfen
#
# Mt
# ‘tty, = 18,55 g/20 mi
# Flussigkeit zum Einnehmen
#
# eas SO ml Wirkstoft: +.
# aN eta C . « Benediktert:
# ley hk Verdauungstropfen i te
# it ty : 18,55 Mischung we
# Ata Wirkstoff: 3,55 g/20 ml do
# “gh, Auszug aus einer Mischung Fjussigkelt zum gem
# mA von Angelikawurzeln, innehmen
# | 4 Benediktenkraut und
# ‘T Pfefferminzblattern
# Wy
# it KLZNGE
#
# PHARMA Zur Anwendung
#
# bei Erwachsenen [ici
#
# Text region detected in image 32.
# Extracted Text from Image 32: nel
# ree eet en
# a ee eae ae Pe ee
# z
#
# ?
# PLSD
#
# ee
# 4407 os
#
# 50 mi i
# > aon,
# Carvomin %
# Verdauungstropfen ;
#
# ao
# 18,55 g/20 ml i,
# Flussigkeit zum Einnehmen
#
# @e
#
# Wirkstoff:
#
# Auszug aus einer Mischung
# von Angelikawurzetn,
# Benediktenkraut und
#
# Pfefferminzblattern
#
# KL3NGE
#
# PHARMA
#
#
# Text region detected in image 33.
# Extracted Text from Image 33: RAS EKA
# Wee ASRS SSE OSS
#
# ~~ SS ey
# “> >= ™
# NaNO ES
#
# won OS
#
# 50 ml
#
# Carvomin
# Verdauungstropfen
#
# 18,55 g/20 ml
# Flussigkeit zum Einnehmen
#
# C
#
# Wirkstoff:
#
# Auszug aus einer Mischung
# von Angelikawurzeln,
# Benediktenkraut und
#
# Pfefferminzblattern
#
# KL3NGE
#
# PHARMA
#
#
# Text region detected in image 34.
# Extracted Text from Image 34:
# No text detected in image 35.
# No text detected in image 36.
# No text detected in image 37.
# No text detected in image 38.
# No text detected in image 39.
# No text detected in image 40.
# Text region detected in image 41.
# Extracted Text from Image 41: hot chocolate
#
# ~< © - hb evn’
#
# Made with Belgian Chocolate
# includes Mini Marshmallows
#
# O O O OC
#
# Milk p int Double Salted
# Chocolate eppermin Chocolate Caramel
#
# =ne ORIGINAL INGREDIENTS: SUGAR, COCOA BUTTER, WHOLE MILK POWDER
# N utr | ti 0 n F a cts MARSHMALLOWS (SUGAR, GLUCOSE SYRUP. GELATIN, SORBITOL, MODIFIED
#
# CORN STARCH, DEXTROSE, ARTFICIAL FLAVOR, TETRASODIUM
# ey R0PHOSPHATE), COCOA MASS, EMULSIFIERS (SOY LECITHIN, PGPR)
# 16 serving per container VANILLA EXTRACT.
#
# Serving size 1 Package (359) Brey
# |
#
# SALTED CARAMEL INGREDIENTS: SUGAR, COCOA BUTTER, WHOLE MILK
# Amount per serving 1 80 POWDER, MARSHMALLOWS (SUGAR, GLUCOSE SYRUP. GELATIN, SORBITOL,
#
# Calories
#
# MODIFIED CORN STARCH, DEXTROSE, ARTFICIAL FLAVOR, TETRASODIUM
# PYROPHOSPHATE). COCOA MASS, EMULSIFIERS (SOY LECITHIN, PGPR),
# VANILLA EXTRACT. SALT, CARAMEL FLAVOR.
#
# % Daily Value* Brae tan)
#
# Total Fat 99
# PEPPERMINT INGREDIENTS: SUGAR, COCOA BUTTER, WHOLE MILK POWDER
#
# Saturated Fat 5g MARSHMALLOWS (SUGAR, GLUCOSE SYRUP, GELATIN, SORBITOL, MODIFIED
# a ve mmm CORI STARCH, DEXTROSE, ARTFICIAL FLAVOR, TETRASODIUM
# Trans Fat 0g PYROPHOSPHATE), COCOA MASS, EMULSIFIERS (SOY LECITHIN, PGPR)
# Cholesterol 5mg VANILLA EXTRACT, PEPPERMINT FLAVOR. BB
# eT iy rye CONTAINS: MILK, SOY.
# Sodium 20mg
# Total Carbohydrate 22g DOUBLE CHOCOLATE INGREDIENTS: SUGAR. COCOA BUTTER, COCOA MASS
# men §— WHOLE MILK POWDER, MARSHMALLOWS (SUGAR, GLUCOSE SYRUP. GELATIN
# Dietary Fiber <1g SORBITOL, MODIFIED CORN STARCH, DEXTROSE, ARTFICIAL FLAVOR
# aera une w eum §—|_TETRASODIUM PYROPHOSPHATE), EMULSIFIERS (SOY LECITHIN, PGPR),
# Total Sugars 219 VANILLA EXTRACT
# Includes 21g Added Sugars 42% MOSCA
#
# Protein 2
# rotein <9 DISTRIBUTED BY FRANKFORD CANDY LLC
#
# ee
#
# Vit. D Omcg 0% © Calcium 45mg 2% Mima walla egal
# ne’ C1000) ATE MADE IN BELGIUM
# lron0.6mg 2% ® Potas. 75mg 2% MOLDED AND PACKED IN CHINA
#
# . MARSHMALLOWS MADE IN CHINA
# *The % Daily Value (DV) tells you how much www.frankfordcandy.com
#
# a nutrient in a serving of food contributes to
# a daily diet. 2,000 calories a day is used for
# general nutrition advice. Frenkferel
#
#
# Text region detected in image 42.
# Extracted Text from Image 42:
# Text region detected in image 43.
# Extracted Text from Image 43: UI998/WWUOZZ
#
# “----------------------->
#
# 305mm/12.00in 32mm/1.25in
#
# Ground Wall Ceiling
#
# No text detected in image 44.
# No text detected in image 45.
# Text region detected in image 46.
# Extracted Text from Image 46: 50cm
#
# de) a
# %r ist 4cm
# FRIF :NDS
#
# 3.5cm
#
# No text detected in image 47.
# No text detected in image 48.
# Text region detected in image 49.
# Extracted Text from Image 49: MGA N|B|U| G4
#
# 1 tablet Cy
#
# Wa ter me
#
# (
#
#
# Text region detected in image 50.
# Extracted Text from Image 50: High Quality Polyester Fabric
# Breathable & Easy to Clean
# Weight: 0.8KG
#
# _ | 45CM
# \
#
#
# No text detected in image 51.
# No text detected in image 52.
# Text region detected in image 53.
# Extracted Text from Image 53:
# Text region detected in image 54.
# Extracted Text from Image 54: WHEY
#
# PROTEIN 90
#
# integratore olimentore di proteine G
#
# Con edulcoranti. Ultrasolubile.
#
# Food supplement of microubrafiltered Sree
# {CFM) whey protein isolote and vikomins. .
# With sweeteners. Uttasoluble.
#
#
# Text region detected in image 55.
# Extracted Text from Image 55: < Material:
# © Colors:
# \
#
# | Weight:
# p Volume:
# >
#
# ¢
#
# \, Shape:
#
# Specifications:
#
# * borosilicate glass
#
# + 3- Natural, Pink, Gold \,
#
# * 160g ia .
# ¢ Shiba Inu |
#
#
# Text region detected in image 56.
# Extracted Text from Image 56: Pero Neto
# 05 70 UNID:
# Hy i
#
# v ht
#
# PINA /
#
# i
#
# 000
#
# 270 g
#
# No text detected in image 57.
# Text region detected in image 58.
# Extracted Text from Image 58: Wy
#
# NUTRIARC
#
# MUSCLE
# [MASS GRINER
#
# CHOCOLATE
# MILKSHAKE
#
#
# No text detected in image 59.
# No text detected in image 60.
# No text detected in image 61.
# Text region detected in image 62.
# Extracted Text from Image 62: ae
#
#
# No text detected in image 63.
# No text detected in image 64.
# No text detected in image 65.
# No text detected in image 66.
# No text detected in image 67.
# No text detected in image 68.
# No text detected in image 69.
# No text detected in image 70.
# No text detected in image 71.
# Text region detected in image 72.
# Extracted Text from Image 72:
# No text detected in image 73.
# Text region detected in image 74.
# Extracted Text from Image 74: Qiaantum
# Naturals
#
# DuantoMilletox
# MILLET SHORTBREAD
# Husk and Fennel
#
# Enhanced With Psyllium
#
# Sweetened with Date SyTUP
#
# ck for boosting energy
#
# All day $"4
#
#
# No text detected in image 75.
# No text detected in image 76.
# No text detected in image 77.
# No text detected in image 78.
# No text detected in image 79.
# Text region detected in image 80.
# Extracted Text from Image 80: Unsere Produkte reduzieren die Betriebskosten
# des Druckers um bis zu 60% und behalten dabei
# den hohen technischen Parameter und die
# Druckqualitat bei.
#
#
# No text detected in image 81.
# No text detected in image 82.
# No text detected in image 83.
# No text detected in image 84.
# No text detected in image 85.
# No text detected in image 86.
# Text region detected in image 87.
# Extracted Text from Image 87: 1.60 INcH
#
# (40.7MM)
#
# Net Weight: 3.2G
#
# an & SS et 444308.
# 925 Sterling Silver Customizable 6.3+2 INCH Extend Chain
# (160mm+50MM)
#
# Manual measurement, the size may be slightly different from the physical.
#
# No text detected in image 88.
# No text detected in image 89.
# No text detected in image 90.
# No text detected in image 91.
# No text detected in image 92.
# Text region detected in image 93.
# Extracted Text from Image 93: Helps to maintain the immune syste™-
# Aide au maintien des fonctions jmmunitaires-
#
# @eo tablets
# comprim
#
#
# No text detected in image 94.
# Text region detected in image 95.
# Extracted Text from Image 95:
# Text region detected in image 96.
# Extracted Text from Image 96: ha
# =~
# SHerbal max
#
# GREEN
# COFFEE
#
# BURN FAT
#
# ———<
#
#
# Text region detected in image 97.
# Extracted Text from Image 97: ae
# SHerbal max
#
# GREEN
# COFFEE
#
# BURN FAT
#
#
# Text region detected in image 98.
# Extracted Text from Image 98: 16G Thick High Grade 304 Stainless Steel
#
# <
# wen é
#
#
# No text detected in image 99.
# Text region detected in image 100.
# Extracted Text from Image 100: Nature’s Way To Wellness
#
# MNO
#
# EASY TO
# SWALLOW
# & DIGEST
#
# Our capsules
# are designed
# to be easily
# swallowed
# and digested,
# manufactured
# in the EU
#
# using the
#
# highest quality ORGANIC
# ingredients. TRIBULUS
#
# 1900.
#
# pHa,
# ve
#
# GMP CERTIFIED
# PRACTICE
#
# Text region detected in image 101.
# Extracted Text from Image 101: KIM JOHANSON
#
# Kaufe 3 Produkte von
# uns und spare 10%
#
# Kaufe 6 Produkte von
# uns und spare 20%
#
# Du kannst unsere Artikel ansehen, wenn du
# auf Kim Johanson direkt beim Produkttitel klickst
# Lege einfach die Artikel in den Warenkorb. Der Rabatt wird automatisch
#
# an der Kasse abgezogen. Klicke dazu auf ,,Zur Kasse gehen".
# Das Angebot gilt fur unser gesamtes Sortiment.
#
# Text region detected in image 102.
# Extracted Text from Image 102: Supplement Facts
#
# Serving Size 2 Capsules
# Servings per Container 30
#
# Amount per Serving % Daily Value
#
# a
# Bioactive Lipid Blend 750 mg *
# Beta sitosterol complex
#
# (>95% sterols / 40% beta sitosterol)
# Berberine HCI
# Botanical Cholesterol Blend 750 mg
# Milk thistle seed extract (80% silymarin)
# Globe artichoke leaf extract
#
# Garlic bulb extract
# a
#
# “Daily value not established.
#
# Other Ingredients: Vegetarian capsule (HPMC), vegetable
# magnesium stearate, bamboo extract.
#
# Artichoke
# Leaf
#
# Berberine
#
# No text detected in image 103.
# No text detected in image 104.
# Text region detected in image 105.
# Extracted Text from Image 105: Stainless steel
# , High polished
#
# \
#
# Silicone material
# Length:13-18cm
# / Weight:9.8g
#
# No text detected in image 106.
# No text detected in image 107.
# No text detected in image 108.
# No text detected in image 109.
# Text region detected in image 110.
# Extracted Text from Image 110: » THIS,
#
#
# Text region detected in image 111.
# Extracted Text from Image 111:
# Text region detected in image 112.
# Extracted Text from Image 112: Necklace Length:50cm/19.68inch
#
# é ct ot
# a ot
# oF 3 c
# a Lane « ay
#
# oe ~
# —
# Ps >
# ‘g Es
# > 2 bo ¥
# se 2
# an
# ar?
# AS) «
# Ps pie -
# oes
# id oe all
# 2 27 i
# % at’ ad a
#
# Weight:4.1g
#
# Text region detected in image 113.
# Extracted Text from Image 113: INFORMATION
#
# {Series] Birthstone Bracelet (Material) Rhodium Plated
#
# (Weight) 9.2 g (About) {Stone Size] 3.5x3.5 mm
#
# Adjustable & ae
#
# Length:175+50 mm
#
# Feo
# YD, “ ns
# NN _~ ‘ ))) . a "
# Bn “Od Rhodium Plated
# Y
# oo
# 9mm
#
# TIPS : manual measuring permissible error.Pleose take the actual product os the standard.
#
# Cubic Zirconia’
#
# Text region detected in image 114.
# Extracted Text from Image 114:
# Text region detected in image 115.
# Extracted Text from Image 115: FEEDING RECOMMENDATIONS
#
# UPTO
#
# 1102
# 20KG BON a DAY
#
# MORE THAN 2 4
# TO
#
# OR AS RECOMMENDED BY
# THE VETERINARIAN
#
# No text detected in image 116.
# No text detected in image 117.
# Text region detected in image 118.
# Extracted Text from Image 118: REHYDRATATION RAPIDE
# APRESLE SPORT ET LAFETE
#
# Equilibre électrolytique’
# plus de 1000 mg d‘électrolytes
#
# Puissance musculaire”
#
# Magnesium & potassium a 7
# gor?
# Support immunitaire’— om
# VitaminesC&B12 _.
#
# 1. Le magnésium contribue a l‘équilibre électrolytique.
# 2.Le potassium et le magnésium contribuent a une fonction musculaire normale.
# 3. Les vitamines C et B12 contribuent a un fonctionnement normal du systeme immunitaire.
#
# No text detected in image 119.
# No text detected in image 120.
# No text detected in image 121.
# Text region detected in image 122.
# Extracted Text from Image 122: Nutrients
#
# Energy
#
# Total Carbohydrate
# Sugar
# Dietary Fiber
#
# Protein
#
# Total Fat
# Saturated Fatty Acids
#
# Amount Per 100 g*
#
# Polyunsaturated Fatty Acids
# Omega 3 Fatty Acids (ALA)
# Monounsaturated Fatty Acids
#
# Trans Fat
#
# Cholesterol
# Calcium
# Magnesium
# Zinc
#
# *Approximate Values
#
# 511.30kcal
# 42.12 g
# 0.0g
# 34.4 g
# 16.54 ¢
# 30.74 ¢
# 3.33 g
# 23.66 g
# 17.8¢g
# 2.30 g
# 0.14g
# Omg
# 631mg
# 335 mg
# 4.58 mg
#
# %RDA**
#
# 25.56
#
# No text detected in image 123.
# Text region detected in image 124.
# Extracted Text from Image 124: & REHYDRATION
# OPTIMIZER
#
# No text detected in image 125.
# No text detected in image 126.
# No text detected in image 127.
# Text region detected in image 128.
# Extracted Text from Image 128: & Diameter Weight: 33g
#
# 8mm
#
# Black Agate Tiger Eye
#
# Durabie doub e ee
#
# Duable Free
# Size Knot
#
# _— —~
#
# (Mex circumference: 11.8” (30cm) >)
# M
#
# \_Min circumference:7.5" (19cm) _/
#
#
# No text detected in image 129.
# No text detected in image 130.
# No text detected in image 131.
# Text region detected in image 132.
# Extracted Text from Image 132:
# No text detected in image 133.
# No text detected in image 134.
# Text region detected in image 135.
# Extracted Text from Image 135:
# Text region detected in image 136.
# Extracted Text from Image 136:
# No text detected in image 137.
# Text region detected in image 138.
# Extracted Text from Image 138: 4.72inch/12cm
#
# E27 Socket
#
# 7.08inch/18cm
#
# AC 100-240V
#
# Max Wattage
#
# 7. 48inch/19cm
#
# BULBS ARE NOT INCLUDED
#
# y | , . w
#
# Fo w u vhs
#
# Text region detected in image 139.
# Extracted Text from Image 139: 4.72inch/12cm
#
# E27 Socket
#
# 7.08inch/18cm
#
# AC 100-240V
#
# Max Wattage
#
# 7. 48inch/19cm
#
# BULBS ARE NOT INCLUDED
#
# y | , . w
#
# Fo w u vhs
#
# No text detected in image 140.
# Text region detected in image 141.
# Extracted Text from Image 141: AE ROLITE EASYJET MAXIMUM CABIN APPROVED
#
# UNDERSEAT BAG
# 2.4kg 28L
# WEIGHT CAPACITY
# qa,
# | {frm}
#
# HANDLE
# HEIGHT
#
# LARGE CAPACITY
#
#
# No text detected in image 142.
# Text region detected in image 143.
# Extracted Text from Image 143: Altezza regolabile 3X Antiruggine
# manubrio inossidabile
#
# ~~ “
#
# Pulsante di smontaggio singolo
# Non sono necessari
# strumenti aggiuntivi
#
# Chiusura in materiale di nylon
# resistentee design unico del
# foro limite altezza regolabile e
#
# piu stabile
#
# Piattaforma extra larga e spessa
# Robusto per contenere fino a 50 kg
#
#
# No text detected in image 144.
# No text detected in image 145.
# No text detected in image 146.
# No text detected in image 147.
# No text detected in image 148.
# No text detected in image 149.
# No text detected in image 150.
# Text region detected in image 151.
# Extracted Text from Image 151:
# Text region detected in image 152.
# Extracted Text from Image 152: SUGGESTED USE:
#
# As a dietary supplement, take 2 capsules
# daily with 8-12 oz of water or as directed by
# your healthcare professional.
#
# WARNING: For healthy individuals 18 years and
# older. Consult a healthcare professional prior to
# use if you are pregnant or nursing, taking
# medication, or have a medical condition. Keep
# out of reach of children. Do not use if safety
# seal is broken or missing.
#
# NOTICE: Store in a cool, dry place.
#
# MADE AND QUALITY TESTED IN THE USA WITH
# GLOBALLY SOURCED INGREDIENTS.
#
# 06 l
#
# 10014 " 674
#
# Distributed by Nutricost®
# 351 E 1750 N Vineyard, UT 84059
# (866) 438-3694 | support@nutricost.com
#
# www.nutricost.com
#
# 404529
# NTC.5.22
#
#
# No text detected in image 153.
# No text detected in image 154.
# No text detected in image 155.
# No text detected in image 156.
# No text detected in image 157.
# No text detected in image 158.
# Text region detected in image 159.
# Extracted Text from Image 159: Lightweight a Packable Ayyaenro:
#
# mz
# Nn ‘
# 0
# ou
# =
# BR
# ~s
# i?)
# =
# 7.9in/20cm
#
# WI9Z/UIETZ OL
#
# AMAL
#
#
# No text detected in image 160.
# Text region detected in image 161.
# Extracted Text from Image 161:
# Text region detected in image 162.
# Extracted Text from Image 162: Nnnnnnnnnr
#
# No text detected in image 163.
# No text detected in image 164.
# No text detected in image 165.
# No text detected in image 166.
# No text detected in image 167.
# Text region detected in image 168.
# Extracted Text from Image 168: PRODUCT DISPLAY
#
# Weight
#
# 30g on 20+15cm
# Adjustable
#
# 15cm/6in
#
# Earent
#
# Free size for women and girls
#
# No text detected in image 169.
# No text detected in image 170.
# No text detected in image 171.
# No text detected in image 172.
# No text detected in image 173.
# No text detected in image 174.
# Text region detected in image 175.
# Extracted Text from Image 175: PREMIUM
# PRODUCT.
#
# CLEAR
# LABELING.
#
# ggested use: Shake before using. Add one
# (1) full squeeze of the dropper bulb to 2 oz. of
# water or juice, 3 times daily, or as directed by
# your healthcare professional.
#
# Caution: If you are pregnant, nursing or
# taking any medications, consult with your
# healthcare provider before use.
#
# Store away from heat and light.
# Keep out of the reach of children.
#
# MULLWO4 EXP 3/26
#
# MUO 01 Ti
# X003RVLMJ3
#
# “THE STAI ONT THIS PRODUCT HAVE NOT BEEN
# EVALUATED BY THE AND DRUG ADMINISTRATION.
# ye IDED TO DIAGNOSE, TREAT,
#
# Wild é, oe |
# organié “_m
#
# MULLEIN LEAF
#
# Third
#
# M,
# Apity BESS Vegam
# USA
#
# 4
# Alcohol-free
# Dietary supplement
#
# Wild &. ,
# organi¢é
#
# Vital information
# conveniently shown
# on the product label.
#
# SUPPLEMENT FACTS
#
# Serving size: 0.7 ml / Servings about 168
#
# ‘Amount Per Serving %DV
# Organic Mullein Leaf 679mg *
# (Verbascum thapsus)
#
# * Daily Value (DV) not established
#
# Manufactured for WILD & ORGANIC, LLC
# 3990 CHEVY CHASE DRIVE LOS ANGELES, CA 90039
# wildorganicsupplements.com
# +17472703836
#
# No text detected in image 176.
# No text detected in image 177.
# Text region detected in image 178.
# Extracted Text from Image 178: Ee ENERG’
#
# PAUTIX
# HH-SW4B0FO0SW24-CO8
#
# 5 plate bes ©
# kWh/1000h 8
#
#
# No text detected in image 179.
# No text detected in image 180.
# Text region detected in image 181.
# Extracted Text from Image 181: Tamiza el a,
# Sieve the matcha
#
# 1gr = 100 ml
#
# Medio cucharilla de matcha Ao
# Half a teaspoon of matcha
#
# How to make
# BONSAI
#
# at home?
# Afiade la leche caliente Afiade un poco
# de tu elleccién
#
# de agua caliente
# Add your choice of hot milk Add a bit of hot water
#
# Mezcla para disolver
#
# Mix to disolve
# i AN
# uy)
#
# BONSAI
# MATCHA
#
#
# Text region detected in image 182.
# Extracted Text from Image 182:
# Text region detected in image 183.
# Extracted Text from Image 183: Up to 1 OOW of Power Delivery
# for Rapid Charging
#
# Charging rate:
#
# Support PD 3.0/PD 2.0/QC 2.0/QC 3.0/AFC
#
# Text region detected in image 184.
# Extracted Text from Image 184: Durable &
# Tangle-Free
#
# Reinforced Cable Joint
# 15000+ Bend Test
#
# Other
#
# No text detected in image 185.
# Text region detected in image 186.
# Extracted Text from Image 186:
# Text region detected in image 187.
# Extracted Text from Image 187: Data Transfer
# up to 5Gbps
#
# No text detected in image 188.
# No text detected in image 189.
# No text detected in image 190.
# Text region detected in image 191.
# Extracted Text from Image 191: CAPACITY
#
# 2.20 inch
# 2 20inch 80ML
#
# J 2.25 inch
# <
# Zs
# { ]
# WEIGHT
#
# —___—E
# 100gm
#
# Text region detected in image 192.
# Extracted Text from Image 192: CHOCOLATE ORANGE
#
# 2 QUENCH <—
# Orange Snack Ber
#
# SH Va
#
#
# Text region detected in image 193.
# Extracted Text from Image 193: CREATINE
#
# GUMMIES
#
# TIES | SIO EISEN
# VEGAN | GLUTEN FREE
# FOOD SUPPLEMENT
#
#
# No text detected in image 194.
# Text region detected in image 195.
# Extracted Text from Image 195: Amount Per Serving (2 Gummies)
#
# Creatine Monohydrate
# * NVR = Nutrient Reference Value
#
# tT =NVR Not Establoshed
#
# INGREDIENTS:
#
# Creatine Monohydrate, Water, Pectin, Citric
# Acid, Soduim Citrate, Natural Flavour, Natural
# Colour, Carnauba Wax, Xylitol, Maltitol.
#
# Ser,.
# Ons wy
#
# 3G
#
# LY
#
#
# No text detected in image 196.
# No text detected in image 197.
# No text detected in image 198.

# %%
extracted_text
# Out:
# 'Amount Per Serving (2 Gummies)\n\nCreatine Monohydrate\n* NVR = Nutrient Reference Value\n\ntT =NVR Not Establoshed\n\nINGREDIENTS:\n\nCreatine Monohydrate, Water, Pectin, Citric\nAcid, Soduim Citrate, Natural Flavour, Natural\nColour, Carnauba Wax, Xylitol, Maltitol.\n\nSer,.\nOns wy\n\n3G\n\nLY\n\n'

# %%
results_df = pd.DataFrame(list(results.items()), columns=['image_link','extracted_text'])
print(results_df)
# Out:
#                                             image_link  \
# 0    https://m.media-amazon.com/images/I/61I9XdN6OF...
# 1    https://m.media-amazon.com/images/I/71gSRbyXmo...
# 2    https://m.media-amazon.com/images/I/61BZ4zrjZX...
# 3    https://m.media-amazon.com/images/I/612mrlqiI4...
# 4    https://m.media-amazon.com/images/I/617Tl40LOX...
# ..                                                 ...
# 190  https://m.media-amazon.com/images/I/718M5ODio0...
# 191  https://m.media-amazon.com/images/I/61lpwH0qHb...
# 192  https://m.media-amazon.com/images/I/712sZRVe98...
# 193  https://m.media-amazon.com/images/I/71d+dz7ogk...
# 194  https://m.media-amazon.com/images/I/51WSQa1ygM...
#
#                                         extracted_text
# 0    PROPSS\n\nNATURE\n\nAcie 100% pure et naturell...
# 1                                    No text detected.
# 2                                    No text detected.
# 3
# 4                          PSYLLIUM\n\nHUSK\n\nFRE\n\n
# ..                                                 ...
# 190                                  No text detected.
# 191  Amount Per Serving (2 Gummies)\n\nCreatine Mon...
# 192                                  No text detected.
# 193                                  No text detected.
# 194                                  No text detected.
#
# [195 rows x 2 columns]

# %%
pd.set_option('display.max_colwidth', None)
results_df.head(10)
# Out:
#                                             image_link  \
# 0  https://m.media-amazon.com/images/I/61I9XdN6OFL.jpg
# 1  https://m.media-amazon.com/images/I/71gSRbyXmoL.jpg
# 2  https://m.media-amazon.com/images/I/61BZ4zrjZXL.jpg
# 3  https://m.media-amazon.com/images/I/612mrlqiI4L.jpg
# 4  https://m.media-amazon.com/images/I/617Tl40LOXL.jpg
# 5  https://m.media-amazon.com/images/I/61QsBSE7jgL.jpg
# 6  https://m.media-amazon.com/images/I/81xsq6vf2qL.jpg
# 7  https://m.media-amazon.com/images/I/71DiLRHeZdL.jpg
# 8  https://m.media-amazon.com/images/I/91Cma3RzseL.jpg
# 9  https://m.media-amazon.com/images/I/71jBLhmTNlL.jpg
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               extracted_text
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                PROPSS\n\nNATURE\n\nAcie 100% pure et naturelle, la tere de\nSoameiéres px tsente des propwidnes abs “s\n\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          No text detected.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          No text detected.
# 3
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                PSYLLIUM\n\nHUSK\n\nFRE\n\n
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        * Naturally-Sourced Psyllium\n\n ———,,\n\n* High strength 1400mg\nper serving\nNS\n\nLANTAGO\nPlant SEEDS\n\n* Suitable for Vegans & Vegetarians\n\n,\n\nHorbaach\n
# 6  Directions: For adults, take two (2) vegan capsules\ndaily, preferably with a meal. Do not exceed stated dose.\n\nNutrition Information\n\nHIGH ST “Typleally Per Daily Dose\nPsyllium Husk Powder 1400mg\n\nIngredients: Psyllium Husk Powder, Capsule Shell (Hy-\ndroxypropylmethylcellulose), Anti-Caking Agents (Mag-\n\nnesium Salts of Fatty Acids, Silicon Dioxide).\nMay contain Sesame Seeds & Mustard. For allergens,\nsee the ingredients in bold.\n\nNotice: Take this product with 220ml of fluids. Taking\nthis product without adequate fluid may cause the pos-\n\nsibility of choking. Do not use this product if you have\n1 4 @) @) MG PLANTAGO OVATA difficulty swallowing. If you experience chest pain, vom-\nPLANT SEEDS iting or difficulty in swallowing or breathing after taking\n\nthis product, seek immediate medical attention. Do not\ntake before sleeping. Fibre products can affect the ab-\nsorption of many medications. Do not take this product\nwithin 1.5 hours of taking medication.\n\nFree From: Artificial Colour, Artificial Flavour, Artificial\nSweetener, Preservatives.\n\nRr\n\nx re} 6 : SUITABLE FOR VEGETARIANS & VEGANS\n\nHU16790 C\n\nHorbaach\n
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          No text detected.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Horbaach\n\n100%\n\nHIGHEST\nQUALITY\n\nPSYLLIUM\nHUSK\n\n_ PLANTAGO OVATA\n\nPLANT SEEDS\n3652\n: CAPSULES:\n\nHorbaach\n
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NEW LOOK.\nSAME TRUSTED QUALITY.\n\nHIGH STRENGTH\n\nPSYLLIUM Wiow $1\nHUSK PSYLLIUM\nHUSK\n\nys Eee\n\nFOOD\nSUPPLEMENT oP QD) ad CAPSULES\n\n~ Horbadach’\n
